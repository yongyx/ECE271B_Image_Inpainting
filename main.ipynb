# %%
import numpy as np
from dataLoader import BatchLoader
from mask import createMask, rectangularMask
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import random
import cv2

# %load_ext autoreload
# %autoreload 2

# %%
datasetRoot = './BG_20K/train/'
trainloader = BatchLoader(datasetRoot, imgHeight=256, imgWidth=256)

# %%
sampleImg1, sampleImgName = trainloader[600]
masked_img, mask = rectangularMask(sampleImg1)

# %%
cv2.imwrite('sampleMask3.jpg', mask.transpose(1,2,0))
# Out:
# True

# %%
cv2.imwrite('sampleImage3.jpg', cv2.cvtColor(sampleImg1.transpose(1,2,0), cv2.COLOR_RGB2BGR))
# Out:
# True

# %%
cv2.imwrite('maskedImg3.jpg', cv2.cvtColor(masked_img.transpose(1,2,0), cv2.COLOR_RGB2BGR))
# Out:
# True

# %%
img = cv2.imread('./sampleMask1.jpg', 1)
# cv2.imshow('image',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# %run main.py --imgRoot './maskedImg3.jpg' --maskRoot './sampleMask3.jpg' --resultName "result4.jpg"
# Out:
# Namespace(imgRoot='./maskedImg3.jpg', maskRoot='./sampleMask3.jpg', resultName='result4.jpg')
# ./maskedImg3.jpg
# Computing bestpatch Mon Mar  6 17:56:31 2023
# best patch finding
# starting updateMats.....
# (150, 195)
# Computing bestpatch Mon Mar  6 17:56:33 2023
# best patch finding
# starting updateMats.....
# (111, 214)
# Computing bestpatch Mon Mar  6 17:56:36 2023
# best patch finding
# starting updateMats.....
# (238, 177)
# Computing bestpatch Mon Mar  6 17:56:38 2023
# best patch finding
# starting updateMats.....
# (161, 116)
# Computing bestpatch Mon Mar  6 17:56:40 2023
# best patch finding
# starting updateMats.....
# (165, 112)
# Computing bestpatch Mon Mar  6 17:56:41 2023
# best patch finding
# starting updateMats.....
# (169, 108)
# Computing bestpatch Mon Mar  6 17:56:42 2023
# best patch finding
# starting updateMats.....
# (146, 196)
# Computing bestpatch Mon Mar  6 17:56:44 2023
# best patch finding
# starting updateMats.....
# (170, 116)
# ...

# %%
img = cv2.imread(sampleImgName)
